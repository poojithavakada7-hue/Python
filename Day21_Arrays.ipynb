# %%
cars = ["Ford", "Volvo", "BMW"]

print(cars)
# Out:
# ['Ford', 'Volvo', 'BMW']

# %%
x = cars[0]
print(x)
# Out:
# Ford

# %%
cars[0] = "Toyota"
print(cars)
# Out:
# ['Toyota', 'Volvo', 'BMW']

# %%
x = len(cars)
