# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
print(thisdict["brand"])
# Out:
# Ford

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020,
  "parts":1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'parts': 1964}

# %%
print(len(thisdict))
# Out:
# 4

# %%
dictionary={
    "brand":"BMW",
    "EV":False,
    "Year":2000,
    "colors":["blue","black","gray"]
}
print(type(dictionary))
print(dictionary)
# Out:
# <class 'dict'>
# {'brand': 'BMW', 'EV': False, 'Year': 2000, 'colors': ['blue', 'black', 'gray']}

# %%
x=dictionary.get("colors")
print(x)
# Out:
# ['blue', 'black', 'gray']

# %%
y=dictionary.keys()
print(y)
z=dictionary.values()
print(z)
# Out:
# dict_keys(['brand', 'EV', 'Year', 'colors'])
# dict_values(['BMW', False, 2000, ['blue', 'black', 'gray']])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}
x = car.values()
print(x)
car["year"] = 2020
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 2020])

# %%
x=thisdict.items()
print(x)
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2020), ('parts', 1964)])

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict:
  print(x)
# Out:
# brand
# model
# year

# %%
for x in thisdict:
  print(thisdict[x])
# Out:
# Ford
# Mustang
# 1964

# %%
for x in thisdict.values():
  print(x)
print("___________")
for x in thisdict.keys():
  print(x)

for x, y in thisdict.items():
  print(x, y)
# Out:
# Ford
# Mustang
# 1964
# ___________
# brand
# model
# year
# brand Ford
# model Mustang
# year 1964
