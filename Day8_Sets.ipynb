# %%
mySet={"pooji","pooja","poojitha"}
print(mySet)
# Out:
# {'pooji', 'poojitha', 'pooja'}

# %%
myset={True,False,1,0}
print(myset)
set1 = ({"apple", 1,  "banana", 0, "cherry"})
print(set1)
print(type(set1))
# Out:
# {False, True}
# {0, 1, 'apple', 'banana', 'cherry'}
# <class 'set'>

# %%
mySet={"pooji","pooja","poojitha","pooji","pooja"}
print(mySet)
# Out:
# {'pooji', 'poojitha', 'pooja'}

# %%
mySet={"pooji","pooja","poojitha"}
print(type(mySet))
print(len(myset))
# Out:
# <class 'set'>
# 2

# %%
mySet={"pooji","pooja","poojitha"}
for i in mySet:
    print(i)
# Out:
# pooji
# poojitha
# pooja

# %%
mySet={"pooji","pooja","poojitha"}
print("pooji" in mySet)
print("pooji" not in mySet)
# Out:
# True
# False

# %%
mySet={"pooji","pooja","poojitha"}
mySet.add("cherry")
print(mySet)
# Out:
# {'pooji', 'poojitha', 'cherry', 'pooja'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'pineapple', 'papaya', 'apple', 'banana', 'mango', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("apple")
print(thisset)
# Out:
# {'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.discard("apple")
print(thisset)
# Out:
# {'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
x=thisset.pop()
print(x)
print(thisset)
# Out:
# apple
# {'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.clear()
print(thisset)
# Out:
# set()

# %%
myset = {"apple", "banana", "cherry"}
del myset
print(myset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 myset = {"apple", "banana", "cherry"}
#       2 del myset
# ----> 3 print(myset)
#
# NameError: name 'myset' is not defined

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1|set2
print(set3)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1&set2
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}
set3 = set1.intersection(set2)
print(set3)
# Out:
# {False, 1, 'apple'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}
set3 = set1.difference(set2)
print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}
set3 = set1.symmetric_difference(set2)
print(set3)
# Out:
# {2, 'banana', 'cherry', 'google'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}
set3 = set1^set2
print(set3)
# Out:
# {2, 'banana', 'cherry', 'google'}

# %%
set1 = frozenset({"apple", 1,  "banana", 0, "cherry"})
print(set1)
print(type(set1))
# Out:
# frozenset({0, 1, 'apple', 'banana', 'cherry'})
# <class 'frozenset'>
