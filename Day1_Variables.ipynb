# %%
x=5
y="pooji"
print(x)
print(y)
# Out:
# 5
# pooji

# %%
x=str(3)
y=int(3)
z=float(3)
print(x,y,z)
# Out:
# 3 3 3.0

# %%
x=5
y="pooji"
z=9.999
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x="pooji"
y='pooji'
print(x==y)
# Out:
# True

# %%
x,y,z="pooji","pooja","poojitha"
print(x,"",y,"",z)
# Out:
# pooji  pooja  poojitha

# %%
x=y=z="pooji"
print(x,"",y,"",z)
# Out:
# pooji  pooji  pooji

# %%
fruits=["apple","banana","cherry"]
x,y,z=fruits
print(x,"",y,"",z)
# Out:
# apple  banana  cherry

# %%
x="I am"
y="Learning"
z="python"
print(x+y+z)
print(x+" "+y+" "+z)
# Out:
# I amLearningpython
# I am Learning python

# %%
x="awesome"
def fun():
    print("Python is "+x)
fun()
# Out:
# Python is awesome

# %%
x="awesome"
def fun():
    x="fantastic"
    print("Python is "+x)
fun()
print("Python is "+x)
# Out:
# Python is fantastic
# Python is awesome

# %%
def fun():
    global x
    x="fantastic"
fun()
print("Python is "+x)
# Out:
# Python is fantastic

# %%
x="awesome"
def fun():
    global x
    x="fantastic"
fun()
print("Python is "+x)
# Out:
# Python is fantastic
