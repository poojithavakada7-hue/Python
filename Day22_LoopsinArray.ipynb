# %%
cars = ["Ford", "Volvo", "BMW"]

for x in cars:
  print(x)
# Out:
# Ford
# Volvo
# BMW

# %%
cars.append("Honda")
print(cars)
# Out:
# ['Ford', 'Volvo', 'BMW', 'Honda']

# %%
cars.pop(1)
print(cars)
# Out:
# ['Ford', 'BMW', 'Honda']
