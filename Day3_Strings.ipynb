# %%
a = "Hello, World!"
print(a[1])
# Out:
# e

# %%
for x in "pooji":
    print(x)
# Out:
# p
# o
# o
# j
# i

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %%
a="Python is a Case sensitive Language."
print("is" in a)
# Out:
# True

# %%
x=input()
a="Python is a Case sensitive Language."
if x in a:
    print("Yes")
else:
    print("No")
# Out:
#  Case
# Yes

# %%
x=input()
a="Python is a Case sensitive Language."
if x not in a:
    print("Yes")
else:
    print("No")
# Out:
#  is
# No

# %%
a="Python is a Case sensitive Language."
print(a[0:12])
# Out:
# Python is a

# %%
a="Python is a Case sensitive Language."
print(a[:12])
# Out:
# Python is a

# %%
a="Python is a Case sensitive Language."
print(a[0:])
# Out:
# Python is a Case sensitive Language.

# %%
a="Python is a Case sensitive Language."
print(a[-2:-12])

# %%
a="Python is a Case sensitive Language."
print(a[-5:-15])

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
a = "  Hello, World!  "
print(a.strip())
# Out:
# Hello, World!

# %%
a = "Hello, World!"
print(a.replace("H","M"))
# Out:
# Mello, World!

# %%
a = "Hello, World!"
print(a.split("e"))
# Out:
# ['H', 'llo, World!']

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a +" " + b
print(c)
# Out:
# Hello World

# %%
john = "doctor"
txt = "My name is John, I want to became a " + john
print(txt)
# Out:
# My name is John, I want to became a doctor

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars
